# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df2 = pd.read_csv('../DataScienceWeek5/Data/ch1_discoveries.csv')
print(df2.dtypes)
# Out:
# date    object
# Y        int64
# dtype: object

# %%
df2['date'] = pd.to_datetime(df2['date'])
print(df2.dtypes)
# Out:
# date    datetime64[ns]
# Y                int64
# dtype: object

# %%
df2 = df2.set_index('date')
df2.plot()
plt.show()

# %%
plt.style.use('ggplot')
df2_sublet = df2['01-01-1850':'01-01-1885']
ax = df2_sublet.plot(color='blue',fontsize=14)
plt.show()

# %%
print(df2_sublet)
# Out:
#              Y
# date
# 1860-01-01   5
# 1861-01-01   3
# 1862-01-01   0
# 1863-01-01   2
# 1864-01-01   0
# 1865-01-01   3
# 1866-01-01   2
# 1867-01-01   3
# 1868-01-01   6
# 1869-01-01   1
# 1870-01-01   2
# 1871-01-01   1
# 1872-01-01   2
# 1873-01-01   1
# 1874-01-01   3
# 1875-01-01   3
# 1876-01-01   3
# 1877-01-01   5
# 1878-01-01   2
# 1879-01-01   4
# 1880-01-01   4
# 1881-01-01   0
# 1882-01-01   2
# 1883-01-01   3
# 1884-01-01   7
# 1885-01-01  12
